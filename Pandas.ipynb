# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Desktop\\Data Framing'

# %%
os.chdir('C:\\Users\\DELL\\Desktop\\Data Framing')

# %%
student_dataset_1=pd.read_excel('student_dataset.xls')

# %%
student_dataset_1
# Out:
#    gender   age  sleeping_time  study_time  mobile_time  sports_time  marks
# 0       f  23.0            8.0         7.0          9.0          4.0    NaN
# 1       m  20.0            7.0         3.0          9.0          4.0    NaN
# 2       m  22.0           12.0         6.0          3.0          3.0    NaN
# 3       f  23.0            6.0         4.0          5.0          3.0    NaN
# 4     NaN  24.0           12.0         3.0          9.0          1.0    NaN
# 5       f  23.0            9.0         3.0          7.0          3.0    NaN
# 6       f   NaN            8.0         3.0          5.0          5.0    NaN
# 7       m  27.0            7.0         5.0          8.0          3.0    NaN
# 8       f  20.0            NaN         4.0          2.0          2.0    NaN
# 9       f  20.0            7.0         7.0          5.0          2.0    NaN
# 10      f  19.0            9.0         NaN          5.0          4.0    NaN
# ...

# %%
student_dataset_1
# Out:
#    gender   age  sleeping_time  study_time  mobile_time  sports_time  marks
# 0       f  23.0            8.0         7.0          9.0          4.0    NaN
# 1       m  20.0            7.0         3.0          9.0          4.0    NaN
# 2       m  22.0           12.0         6.0          3.0          3.0    NaN
# 3       f  23.0            6.0         4.0          5.0          3.0    NaN
# 4     NaN  24.0           12.0         3.0          9.0          1.0    NaN
# 5       f  23.0            9.0         3.0          7.0          3.0    NaN
# 6       f   NaN            8.0         3.0          5.0          5.0    NaN
# 7       m  27.0            7.0         5.0          8.0          3.0    NaN
# 8       f  20.0            NaN         4.0          2.0          2.0    NaN
# 9       f  20.0            7.0         7.0          5.0          2.0    NaN
# 10      f  19.0            9.0         NaN          5.0          4.0    NaN
# ...

# %%
student_dataset_1.groupby(['study_time','age']).agg({'mobile_time':[np.size,np.mean]})
# Out:
#                 mobile_time
#                        size       mean
# study_time age
# 1.0        18.0         2.0   3.500000
#            21.0         1.0   5.000000
#            22.0         1.0   6.000000
#            23.0         3.0   8.000000
#            26.0         1.0   2.000000
# 2.0        18.0         2.0   5.000000
#            21.0         1.0   3.000000
#            22.0         1.0   5.000000
#            23.0         4.0   6.500000
#            24.0         1.0   6.000000
# 3.0        18.0         4.0   4.750000
#            19.0         1.0  10.000000
#            20.0         2.0   7.500000
#            23.0         1.0   7.000000
#            24.0         1.0   9.000000
# 4.0        19.0         1.0   3.000000
#            20.0         3.0   5.000000
#            21.0         1.0        NaN
#            22.0         1.0   4.000000
#            23.0         2.0   4.500000
#            24.0         1.0   6.000000
#            26.0         2.0   7.500000
# ...
